# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

data = pd.read_csv("/content/Employee_Salary_Dataset.csv")
print(data.head())

# Assuming 'Gender' might need encoding if it's categorical and not binary
# If 'Gender' is already numerical (e.g., 0 for one gender, 1 for another),
# you can skip the LabelEncoder step for this column.
# If it's 'Male', 'Female', etc., uncomment and use LabelEncoder or OneHotEncoder
# le_gender = LabelEncoder()
# data["Gender"] = le_gender.fit_transform(data["Gender"])
# print(data.head())

# Assuming 'Salary' is numerical, if it's categorical, use LabelEncoder
# le_salary = LabelEncoder()
# data["Salary"] = le_salary.fit_transform(data["Salary"])
# print(data.head())


x = data[["ID", "Experience_Years", "Age", "Gender", "Salary"]]
print(x.head()) # Use print for better visibility in Colab output

# Assuming 'left' column is not in the new dataset,
# and the user wants to predict something else or this was a mistake.
# Based on the new columns, there is no obvious target variable like 'left'.
# I will assume for now there is no target and just prepare the features.
# If a target variable exists in this dataset, please specify it.

# The original code was predicting 'left', but this column is not in the new dataset.
# I will comment out the target variable selection and model training parts
# as there is no clear target variable based on the provided column list.
# If you have a target variable in this dataset, please let me know which one it is.

# y = data["left"]
# print(y.head())

# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
# lr = LogisticRegression(max_iter=1000)
# lr.fit(x_train, y_train)
# y_lr_pred = lr.predict(x_test)
# print("y_test shape:", y_test.shape)
# print("y_lr_pred shape:", y_lr_pred.shape)
# accuracy_lr = accuracy_score(y_test, y_lr_pred)
# print(accuracy_lr)

print("Data loaded and features selected based on the new dataset.")
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000
# Data loaded and features selected based on the new dataset.
